# %% [markdown]
# 1.引言
#
# 1.1 背景
# 简要介绍项目所涉及的领域和问题，并阐明为什么这个项目是有意义的。（例如，正在分析一组销售数据，以便了解哪些产品卖得最好，或者哪些客户群体最有可能购买您的产品。）
# 心血管疾病在全球范围内是造成死亡和健康问题的主要原因之一。随着生活方式、环境和人口结构的变化，心脏病发作和其他心血管疾病的发病率呈上升趋势。这些疾病不仅给患者本人带来了健康负担，还对整个社会健康系统构成了重要挑战。
#
# 心脏病发作通常发生在心脏供血不足，导致心肌缺血或坏死的情况下。了解和识别心脏病发作的风险因素对于预防和及早干预至关重要。过去的研究表明，年龄、性别、血压、胆固醇水平、心率以及心脏病发作的先兆症状等因素与心血管健康密切相关。
#
# 本数据集提供了一组包含了多种生理和健康参数的信息，这些参数与心脏病发作风险息息相关。我们的目标是通过深入分析这些数据，探索这些参数之间的关联性和潜在的模式，以期能够为心脏健康提供更准确的预测和更个性化的医疗建议。
#
# 这项研究不仅可以为医疗保健领域提供宝贵的见解，还可以帮助制定更精准的预防策略、改善健康政策，并且可能为心血管疾病患者提供更有效的治疗方案。
#
# 这样的扩展能够提供更多有关心血管健康和疾病预防的全局性信息，让读者更好地理解项目的重要性和意义。
#
# 1.2 目的
# 明确项目的目标和研究问题，为读者提供项目的上下文和方向。（例如，希望确定最畅销的产品，或者确定哪些客户群体最有可能购买您的产品。）
# 本项目的首要目标是利用所提供的多维度健康数据集，建立一个可靠的预测模型，以识别出心脏病发作的潜在风险因素。我们希望能够利用年龄、性别、运动诱发性心绞痛、胸痛类型、静息血压、胆固醇水平等关键指标，准确地预测个体可能面临的心脏病发作风险。
#
# 通过这项研究，我们的目标不仅仅是确定独立影响心脏健康的因素，更重要的是理解这些因素之间的相互作用和影响程度。我们希望能够揭示出潜在的、可能未被察觉的模式和趋势，从而为医疗保健专业人员和决策者提供更为全面的数据支持。
#
# 另外，通过分析这些健康指标与心脏病发作风险的关联，我们也希望为个性化的预防措施和治疗方法提供依据。这将有助于医疗保健专业人员更及时地识别高风险患者，并为他们制定更针对性的干预措施，从而降低心血管疾病的发病率和提高患者的生活质量。
#
# 最终，我们的研究目的是为公众健康提供有益的见解和信息，促进更加个性化、精准的医疗保健实践，从而推动心血管健康领域的进步和改善。

# %% [markdown]
# 2. 数据来源
#
# 描述数据集的来源和名称（例如，从公司的销售数据库中提取数据，或者从公共数据源（如网站或社交媒体）上获取数据。），说明如何获取数据以及数据包含哪些字段，如包括数据类型、数据结构、变量名称和单位等。讨论数据的质量，是否存在缺失值、重复项或异常值等问题。此外，还应该说明数据的完整性和准确性，以及进行数据清理和预处理的方法和步骤。
#
# 数据集来源：https://www.kaggle.com/datasets/rashikrahmanpritom/heart-attack-analysis-prediction-dataset/data
# 字段说明：
# Age : Age of the patient
# Sex : Sex of the patient
# exang: exercise induced angina (1 = yes; 0 = no)
# ca: number of major vessels (0-3)
# cp : Chest Pain type chest pain type
# Value 1: typical angina
# Value 2: atypical angina
# Value 3: non-anginal pain
# Value 4: asymptomatic
# trtbps : resting blood pressure (in mm Hg)
# chol : cholestoral in mg/dl fetched via BMI sensor
# fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
# rest_ecg : resting electrocardiographic results
# Value 0: normal
# Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria
# thalach : maximum heart rate achieved
# target : 0= less chance of heart attack 1= more chance of heart attack
#
# 字段数据类型：
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64

# %% [markdown]
# 3. 数据清理
#
# 描述对数据进行的清理步骤，包括处理缺失值、异常值、删除重复项、数据类型转换等。

# %%
import pandas as pd

# 读取CSV文件
file_path = r'C:\Users\dangh\code\Python\homework\heart.csv'
data = pd.read_csv(file_path)

# 定义列名
columns = ['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh', 'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output']
data.columns = columns

# 删除含有小于0的行
for column in columns:
    if column != 'output':  # 排除目标列
        data = data[data[column] >= 0]

# 处理缺失值（示例：用平均值填充）
data.fillna(data.mean(), inplace=True)

# 删除重复项
data.drop_duplicates(inplace=True)

# %% [markdown]
# 4. 数据分析
# 使用Pandas、NumPy等工具，进行数据分析的具体步骤。可以包括计算统计量、创建新特征、分组统计等操作，并提取关键信息和特征，描述数据分布和趋势，分析变量之间的关系和影响等等。描述你对数据的各种分析，例如计算平均值、标准差、频率分布等。

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件
file_path = r'C:\Users\dangh\code\Python\homework\heart.csv'
heart_data = pd.read_csv(file_path)

# 绘制直方图
plt.hist(heart_data['age'], bins=20, alpha=0.7, color='skyblue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages in Heart Data')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取CSV文件
file_path = r'C:\Users\dangh\code\Python\homework\heart.csv'
heart_data = pd.read_csv(file_path)

# 按年龄分组并计算心脏病发作记录的平均值
age_grouped = heart_data.groupby('age')['output'].mean().reset_index()

# 绘制直方图
plt.bar(age_grouped['age'], age_grouped['output'], alpha=0.7, color='skyblue')
plt.xlabel('Age')
plt.ylabel('Average Heart Attack Risk')
plt.title('Average Heart Attack Risk by Age')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取CSV文件
file_path = r'C:\Users\dangh\code\Python\homework\heart.csv'
heart_data = pd.read_csv(file_path)

# 计算相关性矩阵
correlation_matrix = heart_data.corr()

# 绘制热力图
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 8})
plt.title('Correlation Heatmap of Heart Dataset')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取CSV文件
file_path = r'C:\Users\dangh\code\Python\homework\heart.csv'
heart_data = pd.read_csv(file_path)

# 绘制直方图
plt.figure(figsize=(10, 6))
sns.histplot(x='caa', hue='output', data=heart_data, multiple='stack', palette='viridis')
plt.title('Histogram of Major Vessels (caa) with Heart Attack Probability (output)')
plt.xlabel('Number of Major Vessels (caa)')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取CSV文件
file_path = r'C:\Users\dangh\code\Python\homework\heart.csv'
heart_data = pd.read_csv(file_path)

# 绘制直方图
plt.figure(figsize=(10, 6))
sns.histplot(x='cp', hue='output', data=heart_data, multiple='stack', palette='viridis')
plt.title('Histogram of Chest Pain Type (cp) with Heart Attack Probability (output)')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()

# %%
col_cons=['age','trtbps','chol','thalachh','oldpeak']
col_cats=['sex','cp','fbs','restecg','thall','exng','slp','caa']

col_cats=['sex','cp','fbs','restecg','thall','exng','slp','caa']
fig,axs=plt.subplots(2,4,figsize=(15,7),sharey=True)
fig.suptitle('categorical variables')
plt.subplots_adjust(wspace=0.5,hspace=0.5)

sns.set_theme(style='darkgrid',palette='pastel')
sns.countplot(data=data,x='sex',ax=axs[0][0],hue='output')
sns.countplot(data,x='cp',ax=axs[0][1],hue='output')
#axs[0][1].set_title('cp')

sns.countplot(data,x='fbs',ax=axs[0][2],hue='output')
sns.countplot(data,x='restecg',ax=axs[0][3],hue='output')
sns.countplot(data,x='thall',ax=axs[1][0],hue='output')
sns.countplot(data,x='exng',ax=axs[1][1],hue='output')
sns.countplot(data,x='slp',ax=axs[1][2],hue='output')
sns.countplot(data,x='caa',ax=axs[1][3],hue='output')
# Out:
# <Axes: xlabel='caa', ylabel='count'>

# %%
df=pd.read_csv("C:\Users\dangh\code\Python\homework\heart.csv")
df.head()
df["sex"].value_counts()
# Out:
#   Cell In[12], line 1
#     df=pd.read_csv("C:\Users\dangh\code\Python\homework\heart.csv")
#                                                                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']
# 读取CSV文件
file_path = r'C:\Users\dangh\code\Python\homework\heart.csv'
heart_data = pd.read_csv(file_path)

# 绘制直方图
plt.figure(figsize=(10, 6))
sns.histplot(data=heart_data, x='cp', hue='output', multiple='dodge', palette='Set2')
plt.title('胸痛类型与心脏病发作几率关系')
plt.xlabel('胸痛类型')
plt.ylabel('数量')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
# ----> 4 mpl.rcParams['font.sans-serif'] = ['Microsoft YaHei']
#       5 # 读取CSV文件
#       6 file_path = r'C:\Users\dangh\code\Python\homework\heart.csv'
#
# NameError: name 'mpl' is not defined
